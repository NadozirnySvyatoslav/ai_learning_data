# %% [markdown]
# Приклад рекомендаційної системи на основі контента
# ===
# Імпортуємо необхідні бібліотеки
# ---

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Зчитуємо дані - книги
# --

# %%
df = pd.read_csv('datasets/book-crossing/Books.csv',
                on_bad_lines='skip',
                 sep=';'
                )

# %%
df.head()
# Out:
#          ISBN                                              Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  Year                Publisher
# 0    Mark P. O. Morford  2002  Oxford University Press
# 1  Richard Bruce Wright  2001    HarperFlamingo Canada
# 2          Carlo D'Este  1991          HarperPerennial
# 3      Gina Bari Kolata  1999     Farrar Straus Giroux
# 4       E. J. W. Barber  1999   W. W. Norton & Company

# %% [markdown]
# Завантажуємо дані з користувачами та рейтингами

# %%
user_ratings = pd.read_csv('datasets/book-crossing/users-ratings.csv')

# %% [markdown]
# Відфільтруємо дані - працюємо тільки з підмножиною книг, які були прочитані хочаб одним користувачем

# %%
df = df[df['ISBN'].isin(user_ratings['ISBN'])]

# %% [markdown]
# * Заповнимо порожні значення
# * Зтворимо нову змінну text, яка є поєднанням автору та назви

# %%
df.fillna({'Title':'',
           'Author': ''},
          inplace=True)
df['Title'] = df['Title'].apply(lambda s: s.lower())
df['Author'] = df['Author'].apply(lambda s: s.lower())
df['text'] = df['Title'].fillna('') + ' ' + df['Author'].fillna('')

# %% [markdown]
# * Заберемо дублікати за автором та назвою
# * Приберемо порожні значення

# %%
df.drop_duplicates(subset=['Author', 'Title'],inplace=True)
df.dropna(subset=['text'],
          inplace=True)

# %% [markdown]
# Оскільки наступний код спирається на індекси книг у датафрейми, зробимо reset.

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Застосовуємо tfidf для трансформації текста в матрицю

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['text'])

# %% [markdown]
# Рахуємо косинуси між векторами

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# Знайдемо подібні книги до заданої.

# %%
def get_recommendations(isbn, cosine_sim=cosine_sim, top_n = 10):

    idx = df.index[df['ISBN'] == isbn].tolist()[0]

    sim_scores = list(enumerate(cosine_sim[idx]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:top_n + 1] 

    book_indices = [i[0] for i in sim_scores]

    return df.iloc[book_indices]

# %%
df[df['ISBN']=='0440234743']
# Out:
#          ISBN          Title        Author  Year Publisher  \
# 0  0440234743  the testament  john grisham  1999      Dell
#
#                          text
# 0  the testament john grisham

# %%
get_recommendations('0440234743')
# Out:
#            ISBN              Title        Author  Year  \
# 153  0385424728        the chamber  john grisham  1994
# 154  0385472951        the partner  john grisham  1997
# 322  0385510438     the last juror  john grisham  2004
# 61   0385497466       the brethren  john grisham  2000
# 64   0385511612          bleachers  john grisham  2003
# 99   038542471X         the client  john grisham  1993
# 114  044021145X           the firm  john grisham  1992
# 228  044022165X      the rainmaker  john grisham  1996
# 854  0440241073        the summons  john grisham  2002
# 62   0385508042  the king of torts  john grisham  2003
#
#                         Publisher                            text
# 153               Doubleday Books        the chamber john grisham
# 154               Doubleday Books        the partner john grisham
# 322                     Doubleday     the last juror john grisham
# 61                      Doubleday       the brethren john grisham
# 64                      Doubleday          bleachers john grisham
# 99                Doubleday Books         the client john grisham
# 114  Bantam Dell Publishing Group           the firm john grisham
# 228                          Dell      the rainmaker john grisham
# 854       Dell Publishing Company        the summons john grisham
# 62                Doubleday Books  the king of torts john grisham

# %% [markdown]
# Перепишемо фукцію, де тепер рекомендації будуть підбиратися для користувача. Враховуючу його уподобання, та прочитані книги.

# %%
def get_recommendations(user_id, top_n=10):
    high_rated_books = user_ratings[(user_ratings['User-ID']==user_id)&(user_ratings['Rating']>=8)]
    indices = pd.Series(df.index, index=df['ISBN'])
    read_indices = [indices.get(isbn) for isbn in high_rated_books['ISBN'] if isbn in indices]

    sim_scores =sum([cosine_sim[idx] for idx in read_indices if idx is not None])
    sim_scores = sorted(list(enumerate(sim_scores)), key=lambda x: x[1], reverse=True)

    book_indices = [i[0] for i in sim_scores if i[0] not in read_indices][:top_n]
    return df.iloc[book_indices]

# %%
(user_ratings[(user_ratings['User-ID']==243)&(user_ratings['Rating']>8)]
.join(df.set_index('ISBN'), on='ISBN'))
# Out:
#     User-ID  Age        ISBN  Rating                       Title  \
# 0       243  NaN  0060915544      10              the bean trees
# 4       243  NaN  0316601950       9  the pilot's wife : a novel
# 8       243  NaN  0316776963       9      me talk pretty one day
# 14      243  NaN  0375400117      10         memoirs of a geisha
# 27      243  NaN  0425163407       9                         NaN
# 35      243  NaN  0446364800       9      the general's daughter
#
#                 Author    Year        Publisher  \
# 0   barbara kingsolver  1989.0        Perennial
# 4         anita shreve  1999.0   Back Bay Books
# 8        david sedaris  2001.0   Back Bay Books
# 14       arthur golden  1997.0  Alfred A. Knopf
# 27                 NaN     NaN              NaN
# 35      nelson demille  1993.0     Warner Books
#
#                                        text
# 0         the bean trees barbara kingsolver
# 4   the pilot's wife : a novel anita shreve
# 8      me talk pretty one day david sedaris
# 14        memoirs of a geisha arthur golden
# 27                                      NaN
# 35    the general's daughter nelson demille

# %%
get_recommendations(243)
# Out:
#             ISBN                                              Title  \
# 1099  0316788228                                   the pilot's wife
# 279   0099771519                             memoirs of a geisha uk
# 342   0156006529                           where or when  : a novel
# 184   0316789089  the pilot's wife : a novel tag: author of the ...
# 1767  0446611913                                         up country
# 970   0679745203                                the english patient
# 345   0316789844                               resistance : a novel
# 921   0446605409                                        plum island
# 718   0446608262                                    the lion's game
# 810   0060959037                           prodigal summer: a novel
#
#                   Author  Year          Publisher  \
# 1099        anita shreve  2001      Little, Brown
# 279        arthur golden     0   Trafalgar Square
# 342         anita shreve  1999      Harvest Books
# 184         anita shreve  1999      Little, Brown
# 1767      nelson demille  2003      Warner Vision
# 970     michael ondaatje  1996  Vintage Books USA
# 345         anita shreve  1997     Back Bay Books
# 921       nelson demille  1998       Warner Books
# 718       nelson demille  2000       Warner Books
# 810   barbara kingsolver  2001          Perennial
#
#                                                    text
# 1099                      the pilot's wife anita shreve
# 279                memoirs of a geisha uk arthur golden
# 342               where or when  : a novel anita shreve
# 184   the pilot's wife : a novel tag: author of the ...
# 1767                          up country nelson demille
# 970                the english patient michael ondaatje
# 345                   resistance : a novel anita shreve
# 921                          plum island nelson demille
# 718                      the lion's game nelson demille
# 810         prodigal summer: a novel barbara kingsolver
